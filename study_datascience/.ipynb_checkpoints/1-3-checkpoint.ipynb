# %%
users=[{"id":0,"name":"hero"}
       ,{"id":1,"name":"sun"}
       ,{"id":2,"name":"sue"}
       ,{"id":3,"name":"chi"}
       ,{"id":4,"name":"thor"}
       ,{"id":5,"name":"clive"}
       ,{"id":6,"name":"hicks"}
       ,{"id":7,"name":"Devin"}
       ,{"id":8,"name":"kate"}
       ,{"id":9,"name":"klen"}
      ]

# %%
users
# Out:
# [{'id': 0, 'name': 'hero'},
#  {'id': 1, 'name': 'sun'},
#  {'id': 2, 'name': 'sue'},
#  {'id': 3, 'name': 'chi'},
#  {'id': 4, 'name': 'thor'},
#  {'id': 5, 'name': 'clive'},
#  {'id': 6, 'name': 'hicks'},
#  {'id': 7, 'name': 'Devin'},
#  {'id': 8, 'name': 'kate'},
#  {'id': 9, 'name': 'klen'}]

# %%
users[0]
# Out:
# {'id': 0, 'name': 'hero'}

# %%
frendsips=[
    (0,1)
    ,(0,2)
    ,(1,2)
    ,(1,3)
    ,(2,3)
    ,(3,4)
    ,(4,5)
    ,(5,6)
    ,(5,7)
    ,(6,8)
    ,(7,8)
    ,(8,9)
]

# %%
frendsips
# Out:
# [(0, 1),
#  (0, 2),
#  (1, 2),
#  (1, 3),
#  (2, 3),
#  (3, 4),
#  (4, 5),
#  (5, 6),
#  (5, 7),
#  (6, 8),
#  (7, 8),
#  (8, 9)]

# %%
for user in users:
    user["frends"] = []

# %%
user
# Out:
# {'frends': [], 'id': 9, 'name': 'klen'}

# %%
for i,j in frendsips:
    users[i]["frends"].append(users[j])
    users[j]["frends"].append(users[i])

# %%
users
# Out:
# [{'frends': [{'frends': [{...},
#      {'frends': [{...},
#        {...},
#        {'frends': [{...},
#          {...},
#          {'frends': [{...},
#            {'frends': [{...},
#              {'frends': [{...},
#                {'frends': [{...},
#                  {'frends': [{...}, {...}], 'id': 7, 'name': 'Devin'},
#                  {'frends': [{...}], 'id': 9, 'name': 'klen'}],
#                 'id': 8,
#                 'name': 'kate'}],
#               'id': 6,
#               'name': 'hicks'},
#              {'frends': [{...},
#                {'frends': [{'frends': [{...}, {...}],
#                   'id': 6,
#                   'name': 'hicks'},
#                  {...},
#                  {'frends': [{...}], 'id': 9, 'name': 'klen'}],
#                 'id': 8,
#                 'name': 'kate'}],
#               'id': 7,
#               'name': 'Devin'}],
#             'id': 5,
#             'name': 'clive'}],
#           'id': 4,
#           'name': 'thor'}],
# ...

# %%
def numder_of_frends(user):
    return len(user["frends"])

# %%
total_connections = sum(numder_of_frends(user) for user in users)

# %%
total_connections
# Out:
# 24

# %%
from __future__ import division

# %%
num_users = len(users)

# %%
num_users
# Out:
# 10

# %%
avg_connections = total_connections / num_users

# %%
avg_connections
# Out:
# 2.4

# %%
num_frends_by_id = [(user["id"], numder_of_frends(user))
                   for user in users]

# %%
num_frends_by_id
# Out:
# [(0, 2),
#  (1, 3),
#  (2, 3),
#  (3, 3),
#  (4, 2),
#  (5, 3),
#  (6, 2),
#  (7, 2),
#  (8, 3),
#  (9, 1)]

# %%
sorted(num_frends_by_id, key=lambda x: x[0])
# Out:
# [(0, 2),
#  (1, 3),
#  (2, 3),
#  (3, 3),
#  (4, 2),
#  (5, 3),
#  (6, 2),
#  (7, 2),
#  (8, 3),
#  (9, 1)]

# %%
def frends_of_frend_ids_bad(user):
    return [foaf["id"]
           for frends in user["frends"]
           for foaf in frend["frends"]]

# %%
users[0](Hero)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-2190ce5aeb51> in <module>()
# ----> 1 users[0](Hero)
#
# NameError: name 'Hero' is not defined
