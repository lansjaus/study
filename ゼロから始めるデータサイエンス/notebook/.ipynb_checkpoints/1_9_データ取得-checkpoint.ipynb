# %% [markdown]
# # データの取得

# %% [markdown]
# 多くの作業の上、データ取得、整理、変換に費やされる時間が多いです。
# 大抵の場合、データ取得の時間は有益な時間の使い方とは言えない。
# 望ましい形式に変換する方法をここでは扱います。

# %% [markdown]
# ## stdinとstdout

# %% [markdown]
# コマンドラインから実行したのであれば、sys.stdin, stdoutを通じてデータをプログラムに渡せます。
# 以下のスクリプトは、テキストファイルを読み込み正規表現と一致した行を出力します

# %%
# egrep.py
import sys, re

regex= sys.argv[1]
for line in sys.stdin:
    if re.search(regex, line):
        sys.stdout.write(line)

# %%
# テキスト行数カウント
import sys

count=0
for line in sys.stdin:
    count += 1
    
print count
# Out:
# 0

# %%
# 単語の出現回数を数え、頻出するもの表示
import sys
from collections import Counter

try:
    num_words = int(sys.argv[1])
except:
    print "usage: most_common_words.py num words"
    sys.exit(1)

counter = Counter(word.lower() for line in sys.stdin for word in line.strip().split() if word)

for word, count in counter.most_common(num_words):
    sys.stdout.write(str(count))
    sys.stdout.write("\t")
    sys.stdout.write(word)
    sys.stdout.write("\n")
# Out:
# usage: most_common_words.py num words
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %% [markdown]
# ## テキストファイルの基礎
# テキストファイルを使うには、openをつかってfileオブジェクトを作成するが最適のステップ

# %%
# r はread-onlyを意味する
file_for_reading = open('reading_file.txt', 'r')

# w はwriteを表す
file_for_writing = open('writing_file.txt', 'w')

# a はappend
file_for_appending = open('appending_file.txt', 'a')

# ファイルを使い終わったらクローズ
file_for_writind.close()

#以下はエラーになるが気にしない

# %%
# クローズするのを忘れるので。withを利用し自動的にクローズしたほうが良い

filename = ''
with open(filename, 'r') as f:
    data = function_tah_gets_data_from(f)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-21-55c419438b8b> in <module>()
#       2
#       3 filename = ''
# ----> 4 with open(filename, 'r') as f:
#       5     data = function_tah_gets_data_from(f)
#
# IOError: [Errno 22] invalid mode ('r') or filename: ''

# %%
# ファイル全体を読み込む場合
stats_with_hash = 0

input = 'aaaaa'
with open('input_file', 'r') as f:
    for line in f:
        if re.match('^#', line):# 先頭に#の有無を検査
            starts_with_hash += 1

# 上記の方法では、改行文字で終端されている。何か処理を行うのであれば、改行などを取り除きたい。
with open('input_file', encoding='utf-8') as f:
    for line in f:
        line = line.strip().split()
        print(line)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-31-bb57b099a10e> in <module>()
#       3
#       4 input = 'aaaaa'
# ----> 5 with open('input_file', 'r') as f:
#       6     for line in f:
#       7         if re.match('^#', line):# 先頭に#の有無を検査
#
# IOError: [Errno 2] No such file or directory: 'input_file'

# %% [markdown]
# ## 区切り文字のファイル読み込み

# %% [markdown]
# カンマ区切りやタブ区切り
# カンマやタブや改行を含むフィールドが出てく取ると混乱します。独自の構文解析は誤りの元。
# scvモジュールか、pandasライブラリを利用しましょう。

# %%
# csvを読み込む

import csv

# タブ区切り
with open('dilimited_stock_prices.txt', 'rb') as f:
    reader = csv.reader(f, delimiter='\t')
    l = []
    for row in reader:
        #data = row[0]
        #symbol = row[1]
        #closing_price = float(row[2])
        l.append(row)

print(l)    

# ヘッダー付きの場合には、
# reader = csv.reader(f, delimiter='\t')を
# reader = csv.DicRreader(f, delimiter='\t')
# Out:
# [['6/19/2014', 'MSFT', '1.232'], ['6/19/2014', 'FB', '1.1']]

# %%
# ファイル出力
today_price = {'APPL':90.91, 'MSFT':21.68, 'FB':64.5}
print(today_price.items())
with open('comma_dilimited_stock_prices.txt', 'wb') as f:
    writer = csv.writer(f, delimiter='\t')
    for stock, price in today_price.items():
        writer.writerow([stock, price])
# Out:
# [('FB', 64.5), ('APPL', 90.91), ('MSFT', 21.68)]

# %% [markdown]
# ## webスクレイピング
# htmlから情報をデータ取り出すために、Beautiful soupライブラリを使いましょう。
# pythonの組み込みライブラリより優秀なHTTPリクエストライブラリとしてrequestsライブラリをインストールしましょう
# parserとしてhtml5libも入れておきましょう。

# %%
from bs4 import BeautifulSoup
import requests
html = requests.get("http://www.yahoo.co.jp").text
soup = BeautifulSoup(html,'html5lib')
print(soup)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html><head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="text/css" http-equiv="content-style-type"/>
# <meta content="text/javascript" http-equiv="content-script-type"/>
# <meta content="日本最大級のポータルサイト。検索、オークション、ニュース、メール、コミュニティ、ショッピング、など80以上のサービスを展開。あなたの生活をより豊かにする「ライフ・エンジン」を目指していきます。" name="description"/>
# <meta content="noodp" name="robots"/>
# <meta content="fsLMOiigp5fIpCDMEVodQnQC7jIY1K3UXW5QkQcBmVs" name="google-site-verification"/>
# <link href="https://www.yahoo.co.jp/" rel="canonical"/>
# <link href="https://m.yahoo.co.jp/" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="android-app://jp.co.yahoo.android.yjtop/yahoojapan/home/top" rel="alternate"/>
# <title>Yahoo! JAPAN</title>
# <style type="text/css"><!--
# body{word-break:break-all;font:12px/1.22 "Osaka","ＭＳ Ｐゴシック",Arial,sans-serif;*font-size:small;*font:x-small;}
# table{font-size:inherit;font:100%;}
# pre,code,kbd,samp,tt{font-family:monospace;*font-size:108%;line-height:99%;}
# h1,h2,h3,h4,h5{font-size:100%;}
# #p{width:350px;}
# a{color:#1d3994;text-decoration:none;}
# a:visited{color:#941d55;}
# a:hover{text-decoration:underline;}
# --></style>
# <style media="all" type="text/css"><!--
# form{margin:0;}
# #p{border:1px solid #7e9db9;}
#
# .Util-textCenter{text-align:center}.Util-margin0{margin:0 !important}.Util-marginT0{margin-top:0 !important;}.Alert{position:relative;margin:5px 20px 15px;padding:10px;border:1px solid #ffcf16;background-color:#fefac4}.Alert__title{margin-bottom:10px;font-weight:700;font-size:109%}.Alert__body{line-height:1.5}.Alert__logImage{position:absolute;top:0;left:0}.Button{position:relative;display:inline-block;*display:inline;*zoom:1;box-sizing:border-box;margin:0 auto;padding:6px 1em;border-top:1px solid #979797;border-right:1px solid #979797;border-bottom:1px solid #696969;border-left:1px solid #979797;background:#fff;text-align:center;font-size:109%}.Button:hover{border-top:1px solid #5e5e5e;border-right:1px solid #5e5e5e;border-bottom:1px solid #393939;border-left:1px solid #5e5e5e;text-decoration:none}.Button:after{position:absolute;bottom:0;left:0;display:block;width:100%;height:1px;background:#ddd;content:""}
#
# --></style>
# </head>
# <body leftmargin="0" link="#1d3994" marginheight="0" marginwidth="1" topmargin="0" vlink="#941d55">
# <center>
# <table border="0" cellpadding="0" cellspacing="0" width="770"><tbody><tr><td align="center">
# <table bgcolor="#c8d4e4" border="0" cellpadding="1" cellspacing="0" width="100%">
# <tbody><tr>
# <td><table bgcolor="#f9fafe" border="0" cellpadding="1" cellspacing="0" width="100%">
# <tbody><tr>
# <td align="right" width="10%"><img alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="1"/></td>
# <td align="center" width="80%"></td>
# <td align="right" width="10%"><a href="https://www.yahoo-help.jp/"><nobr>ヘルプ</nobr></a></td>
# </tr>
# </tbody></table></td>
# </tr>
# </tbody></table>
# <img alt="" height="10" src="//s.yimg.jp/images/clear.gif" width="1"/><br/>
# <table border="0" cellpadding="0" cellspacing="0">
# <tbody><tr>
# <td><img alt="" border="0" height="59" src="//s.yimg.jp/images/top/sp/cgrade/logo-mh-160929.gif" usemap="#Map" width="734"/>
# <map name="Map">
# <area alt="トラベル" coords="0,1,45,58" href="https://travel.yahoo.co.jp/?sc_e=ytmh" shape="rect"></area>
# <area alt="ヤフオク!" coords="81,1,124,58" href="https://auctions.yahoo.co.jp/" shape="rect"></area>
# <area alt="ショッピング" coords="159,1,204,58" href="https://shopping.yahoo.co.jp/" shape="rect"></area>
# <area alt="Yahoo! JAPAN" coords="256,-1,479,59" href="https://www.yahoo.co.jp/" shape="rect"></area>
# <area alt="プレミアム" coords="530,1,576,57" href="https://premium.yahoo.co.jp/" shape="rect"></area>
# <area alt="カード" coords="605,1,658,57" href="https://card.yahoo.co.jp/service/redirect/top/" shape="rect"></area>
# <area alt="メール" coords="687,1,733,57" href="https://mail.yahoo.co.jp/" shape="rect"></area>
# </map></td>
# </tr>
# </tbody></table>
# <img alt="" height="5" src="//s.yimg.jp/images/clear.gif" width="1"/><br/>
# <!-- SpaceID=0 robot -->
# <!-- SpaceID=0 robot -->
# <!-- SpaceID=0 robot -->
# <img alt="" height="5" src="//s.yimg.jp/images/clear.gif" width="1"/><br/>
# <table bgcolor="#9fb6d5" border="0" cellpadding="1" cellspacing="0" width="100%">
# <tbody><tr>
# <td><table bgcolor="#e9eef4" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tbody><tr>
# <td><table border="0" cellpadding="10" cellspacing="0" width="100%">
# <tbody><tr>
# <td align="center"><form action="https://search.yahoo.co.jp/search" name="sf1">
# <input name="fr" type="hidden" value="top_table"/>
# <input name="tid" type="hidden" value="top_table"/>
# <input name="ei" type="hidden" value="UTF-8"/>
# <table border="0" cellpadding="0" cellspacing="0">
# <tbody><tr>
# <td><table border="0" cellpadding="0" cellspacing="0">
# <tbody><tr>
# <td height="15"><input id="p" name="p" size="20" type="text"/></td>
# <td><img alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="5"/>
# <input alt="ウェブ検索" border="0" name="search" src="//s.yimg.jp/images/top/searchbox/s_w-140325.gif" title="ウェブ検索" type="image"/></td>
# </tr>
# </tbody></table></td>
# </tr>
# <tr>
# <td><img alt="" height="15" src="//s.yimg.jp/images/clear.gif" width="1"/></td>
# </tr>
# <tr>
# <td><input alt="画像" border="0" height="21" name="isearch" src="//s.yimg.jp/images/top/searchbox/s_i-140325.gif" title="画像検索" type="image" width="47"/><img alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="5"/><input alt="動画" border="0" height="21" name="msearch" src="//s.yimg.jp/images/top/searchbox/s_m-140325.gif" title="動画検索" type="image" width="47"/><img alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="5"/><input alt="辞書" border="0" height="21" name="dsearch" src="//s.yimg.jp/images/top/searchbox/s_d-140325.gif" title="辞書検索" type="image" width="47"/><img alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="5"/><input alt="知恵袋" border="0" height="21" name="ksearch" src="//s.yimg.jp/images/top/searchbox/s_k-140325.gif" title="知恵袋検索" type="image" width="47"/><img alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="5"/><input alt="地図" border="0" height="21" name="csearch" src="//s.yimg.jp/images/top/searchbox/s_mp-140325.gif" title="地図検索" type="image" width="47"/><img alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="166"/></td>
# </tr>
# </tbody></table>
# </form></td>
# </tr>
# </tbody></table></td>
# </tr>
# </tbody></table></td>
# </tr>
# </tbody></table>
# <img alt="" height="10" src="//s.yimg.jp/images/clear.gif" width="1"/>
# <table bgcolor="#ffcc01" border="0" cellpadding="1" cellspacing="0" width="100%">
# <tbody><tr>
# <td><table bgcolor="#fefbc4" border="0" cellpadding="0" cellspacing="0" width="100%">
# <tbody><tr><td align="center"><img alt="" height="15" src="//s.yimg.jp/images/clear.gif" width="1"/></td></tr>
# <tr><td align="center">
# <nobr>Yahoo! JAPANトップページの機能を正しくご利用いただくには、下記の環境が必要です。</nobr><br/>
# Windows：Internet Explorer 11.0以上 / Chrome 最新版 / Firefox 最新版 / Microsoft Edge　Macintosh：Safari 9.0以上<img alt="" height="15" src="//s.yimg.jp/images/clear.gif" width="1"/><br/>
# ※Internet Explorer 11.0以上をご利用の場合は、「<a href="https://www.yahoo-help.jp/app/answers/detail/p/533/a_id/43883">Internet Explorerの互換表示について</a>」を参考に、互換表示の無効化をお試しください。<img alt="" height="15" src="//s.yimg.jp/images/clear.gif" width="1"/><br/><img alt="" height="15" src="//s.yimg.jp/images/clear.gif" width="1"/>
# </td>
# </tr>
# </tbody></table></td>
# </tr>
# </tbody></table>
# <img alt="" height="10" src="//s.yimg.jp/images/clear.gif" width="1"/><br/>
# <a href="https://gyao.yahoo.co.jp/special/musicfes/">2大フェス開催　出演アーティストのライブ映像を配信</a> - <a href="https://topics.shopping.yahoo.co.jp/promotion/craftbeer/">専門家が語る、おすすめのクラフトビールや豆知識</a><br/>
# <img alt="" height="10" src="//s.yimg.jp/images/clear.gif" width="1"/>
# <table cellpadding="0" cellspacing="0" width="100%">
# <tbody><tr>
# <td align="left" valign="top">
# <table bgcolor="#d7e0ff" border="0" cellpadding="0" cellspacing="0" width="100%"><tbody><tr><td><img alt="" height="4" src="//s.yimg.jp/images/clear.gif" width="1"/><br/><img alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="10"/><strong>ニュース</strong><br/><img alt="" height="4" src="//s.yimg.jp/images/clear.gif" width="1"/><br/></td></tr><tr><td bgcolor="#9fb6d5"><img alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="1"/></td></tr></tbody></table><table cellpadding="0" cellspacing="10" width="100%"><tbody><tr><td><table border="0" cellpadding="0" cellspacing="4" width="100%"><tbody><tr><td><font color="#666666" size="-3">13時40分更新</font></td></tr><tr><td>・<a href="https://news.yahoo.co.jp/pickup/6281489">GW最終日 高速上りで渋滞も<img alt="動画" border="0" height="11" src="//s.yimg.jp/images/top/sp/cgrade/iconVideo_150713.gif" width="16"/><img alt="NEW" border="0" height="12" src="//s.yimg.jp/images/top/sp/cgrade/iconNew_150713.gif" width="30"/></a></td></tr><tr><td>・<a href="https://news.yahoo.co.jp/pickup/6281492">御岳山 不明の男児を無事保護<img alt="NEW" border="0" height="12" src="//s.yimg.jp/images/top/sp/cgrade/iconNew_150713.gif" width="30"/></a></td></tr><tr><td>・<a href="https://news.yahoo.co.jp/pickup/6281488">西-東日本 7日にかけ大雨警戒<img alt="写真" border="0" height="12" src="//s.yimg.jp/images/top/sp/cgrade/iconPhoto_150713.gif" width="16"/><img alt="NEW" border="0" height="12" src="//s.yimg.jp/images/top/sp/cgrade/iconNew_150713.gif" width="30"/></a></td></tr><tr><td>・<a href="https://news.yahoo.co.jp/pickup/6281481">名古屋城の天守 観光客が殺到<img alt="写真" border="0" height="12" src="//s.yimg.jp/images/top/sp/cgrade/iconPhoto_150713.gif" width="16"/></a></td></tr><tr><td>・<a href="https://news.yahoo.co.jp/pickup/6281484">「ドシン」着陸が正解 本当か<img alt="写真" border="0" height="12" src="//s.yimg.jp/images/top/sp/cgrade/iconPhoto_150713.gif" width="16"/></a></td></tr><tr><td>・<a href="https://news.yahoo.co.jp/pickup/6281486">菊池雄星が抹消 左肩を検査へ<img alt="写真" border="0" height="12" src="//s.yimg.jp/images/top/sp/cgrade/iconPhoto_150713.gif" width="16"/></a></td></tr><tr><td>・<a href="https://news.yahoo.co.jp/pickup/6281483">焼き肉にも 佳純のチーム作り<img alt="写真" border="0" height="12" src="//s.yimg.jp/images/top/sp/cgrade/iconPhoto_150713.gif" width="16"/></a></td></tr><tr><td>・<a href="https://news.yahoo.co.jp/pickup/6281494">朝ドラの主役顔? 奈緒の魅力<img alt="写真" border="0" height="12" src="//s.yimg.jp/images/top/sp/cgrade/iconPhoto_150713.gif" width="16"/><img alt="NEW" border="0" height="12" src="//s.yimg.jp/images/top/sp/cgrade/iconNew_150713.gif" width="30"/></a></td></tr><tr><td><img alt="" height="20" src="//s.yimg.jp/images/clear.gif" width="10"/><a href="https://news.yahoo.co.jp/list/?d=20180506&amp;mc=f&amp;mp=f">もっと見る</a><img alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="40"/><a href="https://news.yahoo.co.jp/fc">記事一覧</a></td></tr></tbody></table></td><td bgcolor="#e9eef4" valign="top" width="140"><table cellpadding="10" cellspacing="0" width="100%%"><tbody><tr><td><center><a href="https://headlines.yahoo.co.jp/hl?a=20180506-00000009-jij_afp-int.view-000"><img alt="王女と一緒に" border="0" height="120" src="https://lpt.c.yimg.jp/im_siggMMnvCq478dO7nPKoSmvhHA---x120-y120/amd/20180506-00000009-jij_afp-000-view.jpg" width="80"/></a></center><a href="https://headlines.yahoo.co.jp/hl?a=20180506-00000009-jij_afp-int.view-000">王女と一緒に</a><br/><font color="#666666" size="-3">5月6日10時31分配信<br/>ＡＦＰ＝時事</font></td></tr></tbody></table></td></tr></tbody></table><img alt="" height="10" src="//s.yimg.jp/images/clear.gif" width="1"/>
# <table bgcolor="#a0b7d6" border="0" cellpadding="1" cellspacing="0" width="100%">
# <tbody><tr>
# <td><table bgcolor="#e9eef4" border="0" cellpadding="4" cellspacing="0" width="100%">
# <tbody><tr>
# <td><table cellpadding="2" cellspacing="0" width="100%">
# <tbody><tr>
# <td valign="top" width="25%"><a href="https://shopping.yahoo.co.jp/?sc_e=ytc">ショッピング</a></td>
# <td valign="top" width="25%"><a href="https://auctions.yahoo.co.jp/">ヤフオク!</a></td>
# <td valign="top" width="25%"><a href="https://lohaco.jp/?bk=t&amp;sc_e=j_as_ya_tc_n&amp;iscr=1">LOHACO</a></td>
# <td valign="top" width="25%"><a href="https://travel.yahoo.co.jp/?sc_e=ytsl">旅行、ホテル予約</a></td>
# </tr>
# <tr>
# <td valign="top"><a href="https://rdsig.yahoo.co.jp/travel_kanko/yjtop_cont/RV=1/RU=aHR0cHM6Ly93d3cuaWt5dS5jb20vaWtDby5hc2h4P2Nvc2lkPWlrMDEwMDAyJnN1cmw9JTJG;_ylt=A2RiVch58mJZ7mAACQR_cQF8">一休.com</a></td>
# <td valign="top"><a href="https://news.yahoo.co.jp/">ニュース</a></td>
# <td valign="top"><a href="https://weather.yahoo.co.jp/weather/">天気</a></td>
# <td valign="top"><a href="https://sports.yahoo.co.jp/">スポーツナビ</a></td>
# </tr>
# <tr>
# <td valign="top"><a href="https://finance.yahoo.co.jp/">ファイナンス</a></td>
# <td valign="top"><a href="https://tv.yahoo.co.jp/">テレビ</a></td>
# <td valign="top"><a href="https://gyao.yahoo.co.jp/">GYAO!</a></td>
# <td valign="top"><a href="https://games.yahoo.co.jp/">ゲーム</a></td>
# </tr>
# <tr>
# <td valign="top"><a href="http://yahoo-mbga.jp/?_ref=aff%3Dysm001">Yahoo!モバゲー</a></td>
# <td valign="top"><a href="https://map.yahoo.co.jp/">地図</a></td>
# <td valign="top"><a href="https://transit.yahoo.co.jp/">路線</a></td>
# <td valign="top"><a href="http://tabelog.com/">食べログ</a></td>
# </tr>
# <tr>
# <td valign="top"><a href="https://job.yahoo.co.jp/">求人、アルバイト</a></td>
# <td valign="top"><a href="https://realestate.yahoo.co.jp/">不動産</a></td>
# <td valign="top"><a href="https://carview.yahoo.co.jp/">自動車</a></td>
# <td valign="top"><a href="https://textream.yahoo.co.jp/">掲示板</a></td>
# </tr>
# <tr>
# <td valign="top"><a href="https://blogs.yahoo.co.jp/">ブログ</a></td>
# <td valign="top"><a href="https://beauty.yahoo.co.jp/">美容、ダイエット</a></td>
# <td valign="top"><a href="https://rdsig.yahoo.co.jp/partner/from_ytop/pc/list1/RV=1/RU=aHR0cHM6Ly9wYXJ0bmVyLnlhaG9vLmNvLmpwLw--">恋愛、婚活</a></td>
# <td valign="top"> </td>
# </tr>
# <tr>
# <td align="right" colspan="4"><strong><a href="https://services.yahoo.co.jp/?mode=pc">&gt;&gt;サービス一覧</a></strong></td>
# </tr>
# </tbody></table></td>
# </tr>
# </tbody></table></td>
# </tr>
# </tbody></table>
# </td>
# <td width="10"> </td>
# <td align="left" valign="top" width="350">
# <table bgcolor="#9fb6d5" border="0" cellpadding="1" cellspacing="0" width="100%">
# <tbody><tr>
# <td><table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tbody><tr>
# <td><table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tbody><tr>
# <td background="//s.yimg.jp/images/top/sp/cgrade/pb_bg.gif" width="10"><img alt="" height="10" src="//s.yimg.jp/images/clear.gif" width="1"/></td>
# <td background="//s.yimg.jp/images/top/sp/cgrade/pb_bg.gif" width="330"><img alt="" height="10" src="//s.yimg.jp/images/clear.gif" width="1"/></td>
# <td background="//s.yimg.jp/images/top/sp/cgrade/pb_bg.gif" width="10"><img alt="" height="10" src="//s.yimg.jp/images/clear.gif" width="1"/></td>
# </tr>
# <tr>
# <td background="//s.yimg.jp/images/top/sp/cgrade/pb_bg.gif" width="10"> </td>
# <td width="330"><table bgcolor="#ffffff" border="0" cellpadding="2" cellspacing="0" width="100%">
# <tbody>
# <tr>
# <td colspan="2"><img alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="7"/><a href="https://login.yahoo.co.jp/config/login?.src=www&amp;.done=https://www.yahoo.co.jp">ログイン</a></td>
# </tr>
# <tr>
# <td><img alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="7"/>IDでもっと便利に[ <a href="https://account.edit.yahoo.co.jp/registration?.src=www&amp;.done=https%3A%2f%2fwww.yahoo.co.jp">新規取得</a> ]</td>
# <td align="right"><a href="https://account.edit.yahoo.co.jp/eval_profile?.src=www&amp;.done=https%3A%2f%2fwww.yahoo.co.jp%2F"><img alt="登録情報" border="0" height="16" src="//s.yimg.jp/images/top/sp/cgrade/info_btn-140325.gif" width="47"/></a><img alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="7"/></td>
# </tr>
# <tr>
# <td colspan="2"><img alt="" height="5" src="//s.yimg.jp/images/clear.gif" width="1"/></td>
# </tr>
# <tr>
# <td><img alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="7"/><strong><a href="https://mail.yahoo.co.jp/"><img align="absmiddle" alt="Yahoo!メール" border="0" height="16" src="//s.yimg.jp/images/top/sp/cgrade/iconMail.gif" width="16"/>メール</a></strong> - <strong><a href="https://mail.yahoo.co.jp/promo/">メールアドレスを取得</a></strong></td>
# </tr>
# <tr>
# <td colspan="2"><img alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="7"/><strong><a href="https://calendar.yahoo.co.jp/">カレンダー</a></strong> - <strong><a href="https://calendar.yahoo.co.jp/info/guide/">カレンダーを活用</a></strong></td>
# </tr>
# </tbody></table></td>
# <td background="//s.yimg.jp/images/top/sp/cgrade/pb_bg.gif" width="10"> </td>
# </tr>
# <tr>
# <td background="//s.yimg.jp/images/top/sp/cgrade/pb_bg.gif" width="10"><img alt="" height="10" src="//s.yimg.jp/images/clear.gif" width="1"/></td>
# <td background="//s.yimg.jp/images/top/sp/cgrade/pb_bg.gif" width="330"><img alt="" height="10" src="//s.yimg.jp/images/clear.gif" width="1"/></td>
# <td background="//s.yimg.jp/images/top/sp/cgrade/pb_bg.gif" width="10"><img alt="" height="10" src="//s.yimg.jp/images/clear.gif" width="1"/></td>
# </tr>
# </tbody></table></td>
# </tr>
# <tr>
# <td bgcolor="#ffffff"><img alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="1"/></td>
# </tr>
# <tr>
# <td><table border="0" cellpadding="5" cellspacing="0" width="100%">
# <tbody><tr>
# <td background="//s.yimg.jp/images/top/sp/cgrade/pb_bg.gif"><img align="top" alt="ポイントを確認" height="16" src="//s.yimg.jp/images/top/sp/cgrade/icon_point.gif" width="25"/><a href="https://points.yahoo.co.jp/" title="ポイントを確認">ポイントを確認</a></td>
# </tr>
# <tr>
# <td background="//s.yimg.jp/images/top/sp/cgrade/pb_bg.gif"><img align="top" alt="" height="1" src="//s.yimg.jp/images/clear.gif" width="5"/><a href="https://lh.login.yahoo.co.jp/" title="ログイン履歴を確認">ログイン履歴を確認</a></td>
# </tr>
# </tbody></table></td>
# </tr>
# </tbody></table></td>
# </tr>
# </tbody></table>
# <img alt="" height="10" src="//s.yimg.jp/images/clear.gif" width="1"/>
# </td>
# </tr>
# </tbody></table>
# <hr color="#cccccc" size="1" width="100%"/>
# <table border="0" cellpadding="4" cellspacing="0" width="100%">
# <tbody><tr>
# <td align="center"><nobr><a href="https://about.yahoo.co.jp/">会社概要</a> - <a href="https://about.yahoo.co.jp/ir/">投資家情報</a> - <a href="https://about.yahoo.co.jp/csr/">社会的責任</a> - <a href="https://about.yahoo.co.jp/info/charter/">企業行動憲章</a> - <a href="https://marketing.yahoo.co.jp/">広告掲載について</a> - <a href="https://about.yahoo.co.jp/hr/">採用情報</a></nobr></td>
# </tr>
# <tr>
# <td align="center"><a href="https://about.yahoo.co.jp/docs/info/terms/">利用規約</a> - <a href="https://about.yahoo.co.jp/docs/pr/disclaimer.html">免責事項</a> - <a href="https://about.yahoo.co.jp/info/mediastatement/">メディアステートメント</a> - <a href="https://about.yahoo.co.jp/docs/info/terms/chapter1.html#cf2nd">プライバシーポリシー</a></td>
# </tr>
# <tr>
# <td align="center">Copyright (C) 2018 Yahoo Japan Corporation. All Rights Reserved.</td>
# </tr>
# </tbody></table>
# </td>
# </tr>
# </tbody></table>
# </center>
#
#
#
#
# </body></html><!-- p11.f7.top.kks.yahoo.co.jp Sun May  6 13:42:45 JST 2018 -->

# %%
# タイトル
first_paragraph = soup.find('title')
first_area = soup.find('area')
print(first_paragraph)
print(first_area)

soup.area.get('href')
# Out:
# <title>Yahoo! JAPAN</title>
# <area alt="トラベル" coords="0,1,45,58" href="https://travel.yahoo.co.jp/?sc_e=ytmh" shape="rect"></area>
# u'https://travel.yahoo.co.jp/?sc_e=ytmh'

# %% [markdown]
# ### オライリーの書籍を読み込んでみる

# %%
url = "http://shop.oreilly.com/"
soup = BeautifulSoup(requests.get(url).text, 'html5lib')

print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
#     <!-- Google Tag Manager -->
#     <script>
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-5P4V6Z');
#     </script>
#     <!-- End Google Tag Manager -->
#
#     <!-- Start Visual Website Optimizer Asynchronous Code -->
#     <script type="text/javascript">
#     var _vwo_code=(function(){
#     var account_id=27087,
#     settings_tolerance=2000,
#     library_tolerance=1500,
#     use_existing_jquery=false,
#     // DO NOT EDIT BELOW THIS LINE
#     f=false,d=document;return{use_existing_jquery:function(){return use_existing_jquery;},library_tolerance:function(){return library_tolerance;},finish:function(){if(!f){f=true;var a=d.getElementById('_vis_opt_path_hides');if(a)a.parentNode.removeChild(a);}},finished:function(){return f;},load:function(a){var b=d.createElement('script');b.src=a;b.type='text/javascript';b.innerText;b.onerror=function(){_vwo_code.finish();};d.getElementsByTagName('head')[0].appendChild(b);},init:function(){settings_timer=setTimeout('_vwo_code.finish()',settings_tolerance);this.load('//dev.visualwebsiteoptimizer.com/j.php?a='+account_id+'&u='+encodeURIComponent(d.URL)+'&r='+Math.random());var a=d.createElement('style'),b='body{opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important;}',h=d.getElementsByTagName('head')[0];a.setAttribute('id','_vis_opt_path_hides');a.setAttribute('type','text/css');if(a.styleSheet)a.styleSheet.cssText=b;else a.appendChild(d.createTextNode(b));h.appendChild(a);return settings_timer;}};}());_vwo_settings_timer=_vwo_code.init();
#     </script>
# <!-- End Visual Website Optimizer Asynchronous Code -->
#
#     <meta charset="utf-8"/>
#     <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#     <meta content="width=device-width, initial-scale=1" name="viewport"/>
#     <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
#     <link href="//www.oreilly.com/favicon.ico" rel="icon" type="image/png"/>
#
#
#
#
#
#
#     <link href="#" rel="shortcut icon" type="image/png"/>
#     <link href="https://cdn.oreillystatic.com/assets/css/2017_font_face.css" rel="stylesheet" type="text/css"/>
#     <link href="https://cdn.oreillystatic.com/assets/css/norm-layout-171020.css" rel="stylesheet" type="text/css"/>
#     <link href="https://cdn.oreillystatic.com/assets/css/norm-conferences-170317.css" rel="stylesheet" type="text/css"/>
#     <link href="https://cdn.oreillystatic.com/assets/css/norm-shop-170705.css" rel="stylesheet" type="text/css"/>
#     <script src="https://cdn.oreillystatic.com/ajax/libs/jquery/1.7.2/jquery.min.js" type="text/javascript"></script>
#
# <title>O'Reilly Media - Tech Books and Videos</title>
# <link href="http://shop.oreilly.com" rel="canonical"/>
# <meta content="2017-06-13" name="search_date"/>
# <meta content="O'Reilly Media - Tech Books and Videos" name="search-title"/>
# <meta content="O'Reilly Media - Tech Books and Videos" name="pagename"/>
# <meta content="O'Reilly" name="site"/>
# <meta content="" name="target"/>
# <meta content="Books and videos from O'Reilly Media, Wiley, No Starch Press, SitePoint, Wrox, and many more." name="description"/>
# <meta content="o'reilly, oreilly, store, oreilly tech books, book store, books, computer books, missing manuals, head first" name="keywords"/>
# <meta content="2017-06-13" name="date"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="O'Reilly Media - Tech Books and Videos" name="twitter:title"/>
# <meta content="http://shop.oreilly.com" name="twitter:url" property="og:url"/>
# <meta content="Books and videos from O'Reilly Media, Wiley, No Starch Press, SitePoint, Wrox, and many more." name="twitter:description" property="og:description"/>
# <meta content="@oreillymedia" name="twitter:site"/>
# <meta content="http://cdn.oreillystatic.com/oreilly/images/oreilly-social-icon-120.png" property="twitter:image"/>
# <meta content="O'Reilly Media - Tech Books and Videos" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="http://cdn.oreillystatic.com/oreilly/images/oreilly-social-icon-200.png" property="og:image"/>
# <meta content="English" name="language_name"/>
# <meta content="English" name="native_language_name"/>
# <meta content="telephone=no" name="format-detection"/>
#
#
# <!--[if lte IE 9]>
# <script>
#   'article aside footer header main nav section time'.replace(/\w+/g,function(n){document.createElement(n)})
# </script>
# <![endif]-->
#
# <!-- start style sheet section -->
# <!--[if lte IE 8]><link rel="stylesheet" href="//cdn.oreillystatic.com/assets/css/norm-layout-170313-ie8.css" type="text/css" /><![endif]-->
# <link href="//cdn.oreillystatic.com/assets/css/norm-shop-171109.css" rel="stylesheet" type="text/css"/>
#
# <!--[if IE 9]>
# <style type="text/css">
#   #menu-toggle:checked ~ .mobile-nav {
#     display:block;
#   }
#   .mobile-nav {
#     display: none;
#   }
#
# </style>
# <![endif]-->
# <style>
# /* homepage styles only */
#   .title-row {
#     border-bottom: 0;
#     margin-bottom: 0;
#   }
#
#   .shop-notice {
#     margin-top: -2.1rem;
#   }
# </style>
# <!-- END style sheet section -->
#
#
# <!--chartbeat-->
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
#
# <!-- SiteCatalyst tracking -->
# <script language="JavaScript" type="text/javascript"><!--
# var s_account="ororeilly,orglobal"
# //--></script>
# <!-- SiteCatalyst code version: H.20.2. Copyright 1997-2009 Omniture, Inc. More info available at http://www.omniture.com  -->
# <script language="JavaScript" src="//cdn.oreillystatic.com/assets/js/s_code.js" type="text/javascript"></script>
# <script language="JavaScript" type="text/javascript"><!--
# s.pageName="oreilly:store:oreilly media - tech books, drm-free ebooks, videos"
# s.channel="oreilly"
# s.prop1="oreilly:store"
# s.prop2="oreilly:store:store"
# s.prop3="oreilly:store:store:store"
# s.prop4=""
# s.prop5="oreilly media - tech books, drm-free ebooks, videos"
# s.prop6="n/csp/4346"
# s.prop24="06/13/2017"
# s.prop21=""
# s.hier1="oreilly,store,store,store"
#
# /************* DO NOT ALTER ANYTHING BELOW THIS LINE ! **************/
# var s_code=s.t();if(s_code)document.write(s_code)//--></script>
# <!-- End SiteCatalyst code version: H.20.2. -->
# <!-- analytics.pl: 2017/6/13 18:55:55 -->
#
# <!--Facebook Insights -->
# <meta content="15137500430" property="fb:page_id"/>
#
# <!-- Google Analytics -->
# <script type="text/javascript">
# var _gaq = _gaq || [];
# _gaq.push(['_setAccount', 'UA-4591498-1']);
# _gaq.push(['_setDomainName', 'oreilly.com']);
# _gaq.push(['_addIgnoredRef', 'oreilly.com']);
# _gaq.push(['_setSiteSpeedSampleRate', 50]);
# _gaq.push(['_trackPageview']);
#
# (function() { var ga = document.createElement('script'); ga.type =
# 'text/javascript'; ga.async = true; ga.src = ('https:' ==
# document.location.protocol ? 'https://ssl' : 'http://www') +
# '.google-analytics.com/ga.js'; var s =
# document.getElementsByTagName('script')[0];
# s.parentNode.insertBefore(ga, s); })();
# </script>
#
#   </head>
#   <body>
#     <!-- Google Tag Manager (noscript) -->
#     <noscript>&lt;iframe src="https://www.googletagmanager.com/ns.html?id=GTM-5P4V6Z" height="0" width="0" style="display:none;visibility:hidden"&gt;&lt;/iframe&gt;</noscript>
#     <!-- End Google Tag Manager (noscript) -->
#     <header role="banner">
#     <div aria-label="site sections" class="branding-bar pa-bg" role="navigation">
#       <a class="logo" href="https://www.oreilly.com" title="home page"><img alt="O'Reilly home" onerror="this.src='//cdn.oreillystatic.com/images/sitewide-headers/oreilly-logo-reversed-130x23.png'; this.onerror=null;" src="//cdn.oreillystatic.com/images/sitewide-headers/oreilly-logo-norm.svg"/></a>
#       <ul class="top-nav" role="menu">
#         <li role="menuitem"><a href="http://www.oreilly.com/ideas">Ideas</a></li>
#         <li role="menuitem"><a href="https://www.safaribooksonline.com/?utm_medium=content&amp;utm_source=oreilly.com&amp;utm_campaign=lgen&amp;utm_content=20170601+nav">Learning Platform</a></li>
#         <li role="menuitem"><a href="http://www.oreilly.com/conferences/">Conferences</a></li>
#         <li role="menuitem"><a href="http://shop.oreilly.com/">Shop</a></li>
#       </ul>
#       <div class="right">
#         <div class="search-nav">
#           <form action="https://ssearch.oreilly.com" class="search-form" method="GET" role="search">
#             <label for="qd"><span class="screen-reader-text">Search terms</span></label>
#             <input class="transparent" id="qd" name="q" placeholder="Search..." type="text" value=""/>
#             <a class="search-cta">
#               <span class="icon-search icon--white">
#                 <svg height="24px" id="search" viewBox="0 0 20 20" width="19px">
#                   <title>Search</title>
#                   <path d="M17.545 15.467l-3.78-3.78a6.15 6.15 0 0 0 .9-3.21c0-3.416-2.962-6.376-6.38-6.376S2.1 4.87 2.1 8.288c0 3.416 2.96 6.377 6.377 6.377 1.137 0 2.2-.31 3.115-.844l3.8 3.8c.37.372.974.372 1.345 0l.943-.942c.37-.37.236-.84-.135-1.21zm-13.54-7.18c0-2.366 1.916-4.283 4.28-4.283S12.76 6.11 12.76 8.478c0 2.365-1.918 4.283-4.283 4.283s-4.473-2.108-4.473-4.473z"></path>
#                 </svg>
#               </span>
#             </a>
#             <input class="hide" type="submit" value="Submit"/>
#           </form>
#         </div>
#
#         <div id="user">
#           <a class="t-c--d" href="http://members.oreilly.com" id="log-out">Your Account</a>
#         </div>
#       </div> <!-- div.right -->
#
#     </div><!-- div.branding_bar -->
#
#     <div id="mobile-menu">
#
#       <input id="menu-toggle" name="menu-toggle" type="checkbox" value="unchecked"/>
#       <label for="menu-toggle">
#          <svg height="34px" id="menu" viewBox="-449 428 20 20" width="34px">
#             <title>Open menu</title>
#             <path d="M-431 433.5c0 .3-.2.5-.5.5h-15c-.3 0-.5-.2-.5-.5v-1c0-.3.2-.5.5-.5h15c.3 0 .5.2.5.5v1zM-431 438.5c0 .3-.2.5-.5.5h-15c-.3 0-.5-.2-.5-.5v-1c0-.3.2-.5.5-.5h15c.3 0 .5.2.5.5v1zM-431 443.5c0 .3-.2.5-.5.5h-15c-.3 0-.5-.2-.5-.5v-1c0-.3.2-.5.5-.5h15c.3 0 .5.2.5.5v1z"></path>
#           </svg>
#           <svg height="34px" id="close" viewBox="-489 391 20 20" width="34px">
#             <title>Close menu</title>
#             <path d="M-477.6 401l4.6-4.6c.2-.2.2-.5 0-.7l-.7-.7c-.2-.2-.5-.2-.7 0l-4.6 4.6-4.6-4.6c-.2-.2-.5-.2-.7 0l-.7.7c-.2.2-.2.5 0 .7l4.6 4.6-4.6 4.6c-.2.2-.2.5 0 .7l.7.7c.2.2.5.2.7 0l4.6-4.6 4.6 4.6c.2.2.5.2.7 0l.7-.7c.2-.2.2-.5 0-.7l-4.6-4.6z"></path>
#           </svg>
#       </label>
#
#       <div aria-label="site sections" class="mobile-nav" role="navigation">
#         <ul class="mobile-top-nav">
#           <li><a href="http://www.oreilly.com/ideas">Ideas</a></li>
#           <li><a href="https://www.safaribooksonline.com/?utm_medium=content&amp;utm_source=oreilly.com&amp;utm_campaign=lgen&amp;utm_content=20170601+nav">Learning Platform</a></li>
#           <li><a href="http://www.oreilly.com/conferences/">Conferences</a></li>
#           <li><a href="http://shop.oreilly.com/">Shop</a></li>
#         </ul>
#
#         <div class="search-nav">
#           <form action="https://ssearch.oreilly.com" class="search-form--m" method="GET" role="search">
#             <label for="qm"><span class="screen-reader-text">Search terms</span></label>
#             <input class="transparent" id="qm" name="q" placeholder="Search..." type="text" value=""/>
#             <a class="search-cta--m">
#               <span class="icon-search icon--black">
#                 <svg height="24px" id="search" viewBox="0 0 20 20" width="19px">
#                   <title>Search</title>
#                   <path d="M17.545 15.467l-3.78-3.78a6.15 6.15 0 0 0 .9-3.21c0-3.416-2.962-6.376-6.38-6.376S2.1 4.87 2.1 8.288c0 3.416 2.96 6.377 6.377 6.377 1.137 0 2.2-.31 3.115-.844l3.8 3.8c.37.372.974.372 1.345 0l.943-.942c.37-.37.236-.84-.135-1.21zm-13.54-7.18c0-2.366 1.916-4.283 4.28-4.283S12.76 6.11 12.76 8.478c0 2.365-1.918 4.283-4.283 4.283s-4.473-2.108-4.473-4.473z"></path>
#                 </svg>
#               </span>
#             </a>
#             <input class="hide" type="submit" value="Submit"/>
#           </form>
#         </div>
#       </div>
#     </div>
#
#     </header>
#     <main id="maincontent" role="main">
#       <div class="title-row">
#       <a href="/" style="display:inline-block;"><h2 class="title">Books &amp; Videos</h2></a>
#       <form action="https://ssearch.oreilly.com/" id="search-form" method="get" name="searchform">
# 					<div class="search">
# 					<fieldset>
# 						<span id="search-input">
# 							<div class="searchInput">
# 								<span id="search-field"><input autocomplete="off" class="yui-ac-input" id="q" maxlength="64" name="q" onfocus="this.value=checkIfDefault(this.value);" placeholder="" type="text"/></span>
# 							</div>
# 							<input id="search-button" type="submit" value="Search"/>
# 						</span>
# 						<div class="yui-ac-container" id="autocomplete"><div class="yui-ac-content" style="display: none;"><div class="yui-ac-hd" style="display: none;"></div><div class="yui-ac-bd"><ul><li style="display: none;"></li><li style="display: none;"></li><li style="display: none;"></li><li style="display: none;"></li><li style="display: none;"></li><li style="display: none;"></li><li style="display: none;"></li><li style="display: none;"></li><li style="display: none;"></li><li style="display: none;"></li></ul></div><div class="yui-ac-ft" style="display: none;"></div></div></div>
# 					</fieldset>
# 					</div>
# 			</form>
#     </div>
#       <div id="banner"></div>
#
#
#
#
#
#   <section class="hero-image">
#     <div class="hero-heading">
#       <section class="hero-heading--section">
#         <h2>Looking for a certain book or video? Get <em>all</em> of them with a <span class="nowrap">Safari membership.</span></h2>
#
#         <p>Whether you want to improve your skills or just need a quick solution to a pressing problem, you’ll be able to find what you need <span class="nowrap">on Safari.</span></p>
#       </section>
#
#       <div class="cta-signup">
#         <a class="btn" href="https://www.safaribooksonline.com/public/free-trial/?utm_medium=content&amp;utm_source=oreilly.com&amp;utm_campaign=lgen&amp;utm_content=20170317+shophomepage+free+trial+form" id="safari-signup">Sign up for a 10-day <span class="nowrap">free trial</span></a>
#         <p>No credit card required</p>
#       </div>
#     </div>
#
#     <div class="hero-options">
#       <div class="hero-options--section">
#         <h3>Explore</h3>
#         <p>Over 40,000 books, videos, and interactive tutorials from over 200 of the world’s best publishers, including O’Reilly, Pearson, HBR, and Packt.</p>
#       </div>
#
#       <div class="hero-options--section">
#         <h3>Follow a path</h3>
#         <p>Expert-curated Learning Paths help you master specific topics with text, video, audio, and interactive coding tutorials.</p>
#       </div>
#
#       <div class="hero-options--section">
#         <h3>Take an online class</h3>
#         <p>Our live, instructor-led online courses get you up to speed quickly on whatever you need to know.</p>
#       </div>
#     </div>
#   </section>
#
#
#
#   <!-- Product Sliders -->
#   <div class="row">
#     <div class="module carousel-module">
#   <h3 class="header">New Books &amp; Videos</h3>
#
#         <section class="carousel-container">
#           <div class="carousel">
#             <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920080237.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920080237'; s.eVar23='orm-slider-0636920080237'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920080237/rc_thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920080237.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920080237'; s.eVar23='orm-slider-0636920080237'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Building Evolutionary Architectures</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/9781680502633.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-9781680502633'; s.eVar23='orm-slider-9781680502633'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/9781680502633/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/9781680502633.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-9781680502633'; s.eVar23='orm-slider-9781680502633'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">React for Real</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920075837.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920075837'; s.eVar23='orm-slider-0636920075837'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920075837/rc_thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920075837.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920075837'; s.eVar23='orm-slider-0636920075837'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Cloud Native Infrastructure</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/9781119247791.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-9781119247791'; s.eVar23='orm-slider-9781119247791'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/9781119247791/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/9781119247791.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-9781119247791'; s.eVar23='orm-slider-9781119247791'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Java All-in-One For Dummies</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920043614.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920043614'; s.eVar23='orm-slider-0636920043614'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920043614/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920043614.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920043614'; s.eVar23='orm-slider-0636920043614'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Intelligence-Driven Incident Response</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/9781680501988.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-9781680501988'; s.eVar23='orm-slider-9781680501988'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/9781680501988/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/9781680501988.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-9781680501988'; s.eVar23='orm-slider-9781680501988'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Effective Testing with RSpec 3</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920038252.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920038252'; s.eVar23='orm-slider-0636920038252'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920038252/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920038252.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920038252'; s.eVar23='orm-slider-0636920038252'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Cloud Native Java</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920032359.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920032359'; s.eVar23='orm-slider-0636920032359'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920032359/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920032359.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920032359'; s.eVar23='orm-slider-0636920032359'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Mobile Game Development with Unity</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920104988.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920104988'; s.eVar23='orm-slider-0636920104988'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920104988/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920104988.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920104988'; s.eVar23='orm-slider-0636920104988'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Mobile App Development with Ionic, Revised Edition</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920115267.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920115267'; s.eVar23='orm-slider-0636920115267'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920115267/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920115267.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920115267'; s.eVar23='orm-slider-0636920115267'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Getting Started with the micro:bit</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/9781681983219.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-9781681983219'; s.eVar23='orm-slider-9781681983219'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/9781681983219/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/9781681983219.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-9781681983219'; s.eVar23='orm-slider-9781681983219'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">David Busch's Nikon D7500 Guide to Digital SLR Photography</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920038481.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920038481'; s.eVar23='orm-slider-0636920038481'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920038481/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920038481.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920038481'; s.eVar23='orm-slider-0636920038481'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Elegant SciPy</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920041313.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920041313'; s.eVar23='orm-slider-0636920041313'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920041313/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920041313.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920041313'; s.eVar23='orm-slider-0636920041313'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Augmented Human</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920051091.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920051091'; s.eVar23='orm-slider-0636920051091'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920051091/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920051091.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920051091'; s.eVar23='orm-slider-0636920051091'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Test-Driven Development with Python</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920031543.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920031543'; s.eVar23='orm-slider-0636920031543'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920031543/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920031543.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920031543'; s.eVar23='orm-slider-0636920031543'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Getting Started with 3D Carving</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920063698.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920063698'; s.eVar23='orm-slider-0636920063698'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920063698/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920063698.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920063698'; s.eVar23='orm-slider-0636920063698'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Learning TensorFlow</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920037316.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920037316'; s.eVar23='orm-slider-0636920037316'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920037316/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920037316.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920037316'; s.eVar23='orm-slider-0636920037316'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Interactive Data Visualization for the Web</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920053576.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920053576'; s.eVar23='orm-slider-0636920053576'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920053576/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920053576.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920053576'; s.eVar23='orm-slider-0636920053576'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Learning FPGAs</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920056669.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920056669'; s.eVar23='orm-slider-0636920056669'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920056669/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920056669.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920056669'; s.eVar23='orm-slider-0636920056669'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Modern Java Recipes</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/9781680502619.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-9781680502619'; s.eVar23='orm-slider-9781680502619'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/9781680502619/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/9781680502619.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-9781680502619'; s.eVar23='orm-slider-9781680502619'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Mastering Ruby Closures</a></p></div>
#
# </div>
#
#
#
#
#
#
#
#
#           </div>
#
#           <a class="arrow left hidden" href="#"></a>
#           <a class="arrow right" href="#"></a>
#           <div class="dots"></div>
#         </section>
#     </div>
# </div>
#
#
# <div class="row">
#     <div class="module carousel-module">
#   <h3 class="header">Training Videos</h3>
#
#         <section class="carousel-container">
#           <div class="carousel">
#             <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920056539.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920056539'; s.eVar23='orm-slider-0636920056539'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920056539/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920056539.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920056539'; s.eVar23='orm-slider-0636920056539'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Testing in Go</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920086284.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920086284'; s.eVar23='orm-slider-0636920086284'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920086284/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920086284.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920086284'; s.eVar23='orm-slider-0636920086284'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Information Management Using Azure Data Factory</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920090229.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920090229'; s.eVar23='orm-slider-0636920090229'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920090229/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920090229.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920090229'; s.eVar23='orm-slider-0636920090229'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Data Science Fundamentals for Marketing and Business Professionals</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920102755.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920102755'; s.eVar23='orm-slider-0636920102755'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920102755/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920102755.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920102755'; s.eVar23='orm-slider-0636920102755'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Advanced Concepts of Odoo 10</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920102748.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920102748'; s.eVar23='orm-slider-0636920102748'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920102748/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920102748.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920102748'; s.eVar23='orm-slider-0636920102748'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Building Electron Applications</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920078111.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920078111'; s.eVar23='orm-slider-0636920078111'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920078111/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920078111.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920078111'; s.eVar23='orm-slider-0636920078111'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Using IPV6 with AWS Virtual Private Cloud (VPC)</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920102700.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920102700'; s.eVar23='orm-slider-0636920102700'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920102700/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920102700.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920102700'; s.eVar23='orm-slider-0636920102700'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">AWS for Administrators</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920102762.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920102762'; s.eVar23='orm-slider-0636920102762'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920102762/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920102762.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920102762'; s.eVar23='orm-slider-0636920102762'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">The Ultimate Hands-on Hadoop</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920085287.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920085287'; s.eVar23='orm-slider-0636920085287'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920085287/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920085287.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920085287'; s.eVar23='orm-slider-0636920085287'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Administering a SQL Database Infrastructure - Exam 70-764 Certification Training</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920086581.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920086581'; s.eVar23='orm-slider-0636920086581'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920086581/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920086581.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920086581'; s.eVar23='orm-slider-0636920086581'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Mining the Social Web - Facebook</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920097464.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920097464'; s.eVar23='orm-slider-0636920097464'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920097464/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920097464.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920097464'; s.eVar23='orm-slider-0636920097464'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Implementing and Testing Applications using Functional JavaScript</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920086536.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920086536'; s.eVar23='orm-slider-0636920086536'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920086536/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920086536.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920086536'; s.eVar23='orm-slider-0636920086536'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Introduction to Cognitive Computing with IBM Watson Services</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920077275.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920077275'; s.eVar23='orm-slider-0636920077275'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920077275/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920077275.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920077275'; s.eVar23='orm-slider-0636920077275'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Mastering Meetings and Workshops with the Whiteboard</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920072904.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920072904'; s.eVar23='orm-slider-0636920072904'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920072904/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920072904.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920072904'; s.eVar23='orm-slider-0636920072904'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Understanding Anomaly Detection</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920097112.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920097112'; s.eVar23='orm-slider-0636920097112'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920097112/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920097112.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920097112'; s.eVar23='orm-slider-0636920097112'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Introducing Microsoft Team Foundation Server 2017</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# <a class="block" href="//shop.oreilly.com/product/0636920097143.do" itemprop="url" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920097143'; s.eVar23='orm-slider-0636920097143'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');"><img alt="" itemprop="image" src="//akamaicovers.oreilly.com/images/0636920097143/thumb.gif"/></a><div class="metadata"><p class="title"><a href="//shop.oreilly.com/product/0636920097143.do" itemprop="name" onclick="var s=s_gi(s_account); s.products=';orm-slider-0636920097143'; s.eVar23='orm-slider-0636920097143'; s.events='event5'; s.linkTrackVars='eVar23,products,events'; s.linkTrackEvents='event5'; s.tl(this,'o','Ad Click');">Understanding Bot Framework</a></p></div>
#
# </div>
#
#
#
#
#
#
#
# <div class="carousel-item" itemscope="" itemtype="//schema.org/Product">
#
# ...
#
#         //if all items can be visible at one time
#         //make the carousel width 100%, and hide navigation elements
#         if (carouselSize >= carouselLength) {
#           $(this).find('.carousel').css('width', '100%');
#           dots.css('visibility','hidden');
#           $(this).find('.arrow').addClass('hidden');
#         }
#         //else, make the carousel width fit the total items, and show navigation elements
#         else {
#           $(this).find('.carousel').css('width', (carouselLength / carouselSize * 100) + '%');
#           dots.css('visibility','visible');
#
#           dots.find('a').each(function(i) {
#             $(this).removeClass('dot');
#             if (i < slideNum) {
#               $(this).addClass('dot');
#             }
#           });
#
#           //Set current dot and left margin
#           if ($(this).data('left') != 0 && $(this).data('left') != undefined) {
#             if (!dots.find('.current').hasClass('dot')) {
#               dots.find('.current').removeClass('current');
#               dots.find('.dot:last').addClass('current');
#             }
#             var newLeftPos = dots.find('.current').index() * -100;
#             if (newLeftPos < (carouselLength / carouselSize * -100) + 100) {
#               newLeftPos = (carouselLength / carouselSize * -100) + 100;
#             }
#             else {
#               newLeftPos = dots.find('.current').index() * -100;
#             }
#             $(this).find('.carousel').css({'margin-left' : newLeftPos + '%', 'transition' : 'none'});
#
#             hideShowArrows($(this), newLeftPos, (carouselLength / carouselSize * -100) + 100);
#           }
#         }
#
#         $(this).data('size', carouselSize);
#       }
#     });
#   }
#
#   function setCarouselNavigation() {
#     $('.carousel-container').each(function() {
#       var thisCarousel = $(this);
#
#       var swipeStartX, swipeStartY, swipeDist, swipeStartTime, swipeElapsedTime;
#       var swipeMinDist = 50;
#       var swipeMaxTime = 500;
#
#       thisCarousel.bind('touchstart mousedown', function(e) {
#         swipeStartX = e.pageX;
#         swipeStartY = e.pageY;
#         swipeDist = 0;
#         swipeStartTime = new Date().getTime();
#       });
#
#       thisCarousel.bind('touchend mouseup', function(e) {
#         swipeDist = e.pageX - swipeStartX;
#         swipeElapsedTime = new Date().getTime() - swipeStartTime;
#
#         if (swipeElapsedTime <= swipeMaxTime) {
#           if (Math.abs(swipeDist) >= swipeMinDist) {
#             if (Math.abs(e.pageY - swipeStartY) <= 100) {
#               if (swipeDist > 0) {
#                 thisCarousel.find('.arrow.left').click();
#               }
#               else {
#                 thisCarousel.find('.arrow.right').click();
#               }
#             }
#           }
#         }
#       });
#
#       thisCarousel.find('.dots a').click(function(e) {
#         e.preventDefault();
#
#         var dot = $(this);
#         if (!dot.hasClass('current')) {
#           dot.siblings().removeClass('current');
#           dot.addClass('current');
#           var newLeftPos = (dot.index() * -100);
#
#           var carouselLength = thisCarousel.find('.carousel-item').length;
#           if (newLeftPos < (carouselLength / thisCarousel.data('size') * -100) + 100) {
#             newLeftPos = (carouselLength / thisCarousel.data('size') * -100) + 100;
#           }
#
#           thisCarousel.find('.carousel').css({'margin-left' : newLeftPos + '%', 'transition' : 'margin .5s'});
#           thisCarousel.data('left', newLeftPos);
#
#           hideShowArrows(thisCarousel, newLeftPos, (carouselLength / thisCarousel.data('size') * -100) + 100);
#         }
#       });
#
#       thisCarousel.find('.arrow').click(function(e) {
#         e.preventDefault();
#
#         var arrow = $(this);
#         if (arrow.hasClass('left')) {
#           var newLeftPos = thisCarousel.data('left') + 100;
#
#           if (newLeftPos > 0) {
#             newLeftPos = 0;
#           }
#
#           thisCarousel.find('.carousel').css({'margin-left' : newLeftPos + '%', 'transition' : 'margin .5s'});
#           thisCarousel.data('left', newLeftPos);
#
#           hideShowArrows(thisCarousel, newLeftPos, (carouselLength / thisCarousel.data('size') * -100) + 100);
#         }
#         else if (arrow.hasClass('right')) {
#           var newLeftPos = thisCarousel.data('left') - 100;
#           var carouselLength = thisCarousel.find('.carousel-item').length;
#           if (newLeftPos < (carouselLength / thisCarousel.data('size') * -100) + 100) {
#             newLeftPos = (carouselLength / thisCarousel.data('size') * -100) + 100;
#           }
#
#           thisCarousel.find('.carousel').css({'margin-left' : newLeftPos + '%', 'transition' : 'margin .5s'});
#           thisCarousel.data('left', newLeftPos);
#
#           hideShowArrows(thisCarousel, newLeftPos, (carouselLength / thisCarousel.data('size') * -100) + 100);
#         }
#
#         newCurrentDot = Math.ceil(-newLeftPos / 100);
#         thisCarousel.find('.dots a').removeClass('current');
#         thisCarousel.find('.dots a:eq(' + newCurrentDot + ')').addClass('current');
#       });
#     });
#   }
#
#
#   //Hide or show arrows at boundaries
#   function hideShowArrows(carousel, pos, end) {
#     if (pos == 0) {
#       carousel.find('.arrow.left').addClass('hidden');
#     }
#     else {
#       carousel.find('.arrow.left').removeClass('hidden');
#     }
#
#     if (pos == end) {
#       carousel.find('.arrow.right').addClass('hidden');
#     }
#     else {
#       carousel.find('.arrow.right').removeClass('hidden');
#     }
#   }
#
#   jQuery(document).ready(function($) {
#     $(window).resize(function(e) {
#       resizeCarousels();
#     });
#     resizeCarousels();
#
#     setCarouselNavigation();
#   });
#
# </script>
#
# <div style="height: 0 !important; width: 0 !important; line-height: 0 !important; font-size: 0 !important; margin-top: -13px; float: left;">
#
#
#
#
#
# <script type="text/javascript">
#     adroll_adv_id = "ZMY7MBBFIFDUBAVNOE7XUJ";
#     adroll_pix_id = "JPUOHWQVQZBGBBTRCVCUVP";
#     /* OPTIONAL: provide email to improve user identification */
#     /* adroll_email = "username@example.com"; */
#     (function () {
#         var _onload = function(){
#             if (document.readyState && !/loaded|complete/.test(document.readyState)){setTimeout(_onload, 10);return}
#             if (!window.__adroll_loaded){__adroll_loaded=true;setTimeout(_onload, 50);return}
#             var scr = document.createElement("script");
#             var host = (("https:" == document.location.protocol) ? "https://s.adroll.com" : "http://a.adroll.com");
#             scr.setAttribute('async', 'true');
#             scr.type = "text/javascript";
#             scr.src = host + "/j/roundtrip.js";
#             ((document.getElementsByTagName('head') || [null])[0] ||
#                 document.getElementsByTagName('script')[0].parentNode).appendChild(scr);
#         };
#         if (window.addEventListener) {window.addEventListener('load', _onload, false);}
#         else {window.attachEvent('onload', _onload)}
#     }());
# </script>
#
#
#
# </div>
#
# <script type="text/javascript">
#     var _sf_async_config = _sf_async_config || {};
#     /** CONFIGURATION START **/
#     _sf_async_config.uid = 1632;
#     _sf_async_config.domain = 'oreilly.com';
#     _sf_async_config.useCanonical = true;
#     /** CONFIGURATION END **/
#     (function() {
#         function loadChartbeat() {
#             var e = document.createElement('script');
#             e.setAttribute('language', 'javascript');
#             e.setAttribute('type', 'text/javascript');
#             e.setAttribute('src', '//static.chartbeat.com/js/chartbeat.js');
#             document.body.appendChild(e);
#         }
#         var oldonload = window.onload;
#         window.onload = (typeof window.onload != 'function') ?
#             loadChartbeat : function() {
#                 oldonload();
#                 loadChartbeat();
#             };
#     })();
# </script>
#
# <!-- Crazyegg async script -->
# <script type="text/javascript">
# setTimeout(function(){var a=document.createElement("script");
# var b=document.getElementsByTagName("script")[0];
# a.src=document.location.protocol+"//script.crazyegg.com/pages/scripts/0011/6381.js?"+Math.floor(new Date().getTime()/3600000);
# a.async=true;a.type="text/javascript";b.parentNode.insertBefore(a,b)}, 1);
# </script>
#
#     </main>
#     <footer role="contentinfo">
#
#     <div class="footer-top">
#       <div class="footer-inner">
#
#         <div aria-label="company info" class="about-us" role="navigation">
#           <h3 class="title">About Us</h3>
#           <ul role="menu">
#             <li role="menuitem"><a href="http://www.oreilly.com/about/">Our Company</a></li>
#             <li role="menuitem"><a href="http://www.oreilly.com/work-with-us.html">Teach/Speak/Write</a></li>
#             <li role="menuitem"><a href="http://www.oreilly.com/careers/"> Careers </a></li>
#             <li role="menuitem"><a href="http://shop.oreilly.com/category/customer-service.do">Customer Service</a></li>
#             <li role="menuitem"><a href="http://www.oreilly.com/about/contact.html">Contact Us</a></li>
#           </ul>
#         </div>
#
#         <div aria-label="social media links" class="social" role="navigation">
#           <ul role="menu">
#             <li role="menuitem">
#               <a class="icon-link" href="http://twitter.com/oreillymedia">
#                 <span class="icon icon-twitter t-fill icon--white">
#                   <svg height="20" id="twitter" viewBox="0 0 24.61 20" width="24.61" xmlns="http://www.w3.org/2000/svg"><title>Twitter</title><path d="M22.09,5c0,.22,0,.44,0,.65A14.27,14.27,0,0,1,7.74,20,14.28,14.28,0,0,1,0,17.73a10.54,10.54,0,0,0,1.2.07,10.13,10.13,0,0,0,6.27-2.16,5.06,5.06,0,0,1-4.72-3.5A5.16,5.16,0,0,0,5,12,5.06,5.06,0,0,1,1,7.1V7a5,5,0,0,0,2.29.63A5,5,0,0,1,1.71.92,14.33,14.33,0,0,0,12.12,6.2,5.1,5.1,0,0,1,12,5a5,5,0,0,1,5-5h0a5,5,0,0,1,3.69,1.59A10.17,10.17,0,0,0,23.93.37a5.07,5.07,0,0,1-2.22,2.79,10.1,10.1,0,0,0,2.9-.79A10.2,10.2,0,0,1,22.09,5Z"></path></svg>
#                 </span>
#               </a>
#             </li><li role="menuitem">
#               <a class="icon-link" href="http://fb.co/OReilly">
#                 <span class="icon icon-facebook t-fill icon--white">
#                   <svg height="20" id="facebook" viewBox="0 0 11.11 20" width="11.11" xmlns="http://www.w3.org/2000/svg"><title>Facebook</title><path d="M11.11,3.48H7.94c-.38,0-.79.49-.79,1.15V6.92h4l-.6,3.27H7.14V20H3.4V10.19H0V6.92H3.4V5A4.71,4.71,0,0,1,7.94,0h3.17V3.48Z"></path></svg>
#                 </span>
#               </a>
#             </li><li role="menuitem">
#               <a class="icon-link" href="https://www.linkedin.com/company/o%27reilly-media">
#                 <span class="icon icon-linkedin t-fill icon--white">
#                   <svg height="20" id="linkedin" viewBox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg"><title>LinkedIn</title><path d="M4.46,2.29A2.07,2.07,0,0,1,2.29,4.46,2.07,2.07,0,0,1,.13,2.29,2.26,2.26,0,0,1,2.29,0,2.26,2.26,0,0,1,4.46,2.29ZM0,20V5.61H4.46V20ZM6.5,6.11h3.95L10.7,8h.13A4.79,4.79,0,0,1,15,5.86c2.8,0,5,1.91,5,5.86V20H15.54V12.36c0-1.78-.64-3.06-2.17-3.06a2.18,2.18,0,0,0-2,1.78,2.48,2.48,0,0,0-.13,1V20H6.75V10.45S6.62,7.26,6.5,6.11Z"></path></svg>
#                 </span>
#               </a>
#             </li><li role="menuitem">
#               <a class="icon-link" href="https://www.youtube.com/user/OreillyMedia">
#                 <span class="icon icon-youtube-large t-fill icon--white">
#                   <svg height="20" id="youtube-large" viewBox="0 0 47.87 20" width="47.87" xmlns="http://www.w3.org/2000/svg"><title>YouTube</title><path d="M16.06,13.89c-.4.54-.69.86-1.06.86s-.34-.09-.4-.37V6.51H12.8v7.66a3.92,3.92,0,0,0,.2,1.4,1.09,1.09,0,0,0,1.14.71c.63,0,1.2-.4,1.91-1.17v1.06h1.83V6.51H16.06v7.37ZM8.91,6.46a2.27,2.27,0,0,0-2,.94,3.88,3.88,0,0,0-.57,2.31v3.43a3.51,3.51,0,0,0,.54,2.2,2.56,2.56,0,0,0,2,1,2.66,2.66,0,0,0,2.06-1,3.51,3.51,0,0,0,.54-2.2V9.66a3.88,3.88,0,0,0-.57-2.31,2.57,2.57,0,0,0-2-.89Zm0,8.31c-.57,0-.86-.49-.77-1.43V9.49c-.09-1,.2-1.4.77-1.4s.86.46.77,1.4v3.83C9.74,14.29,9.46,14.77,8.91,14.77ZM4.69,3.29l-1.31,5L2,3.29H0c.4,1.2,2.4,7.66,2.4,7.66v5.29H4.31V10.94l2.4-7.66ZM36.57,8.06a1.41,1.41,0,0,0-.91.43v5.8a1.24,1.24,0,0,0,.91.43c.49,0,.71-.37.71-1.34V9.31c0-1-.2-1.26-.71-1.26ZM43.71,9.2c0-.89-.23-1.14-.8-1.14s-.83.23-.83,1.14v1.06h1.63Zm3.91-4.89a6.35,6.35,0,0,0-1.11-2.83A4.14,4.14,0,0,0,43.66.29c-4-.29-10-.29-10-.29s-6,0-10,.29a4,4,0,0,0-2.86,1.2,6,6,0,0,0-1.11,2.83,43.12,43.12,0,0,0-.29,4.6v2.14a42.42,42.42,0,0,0,.29,4.6,6.35,6.35,0,0,0,1.11,2.83,4.9,4.9,0,0,0,3.14,1.2c2.23.23,9.66.31,9.66.31s6,0,10-.31a4,4,0,0,0,2.86-1.2,6,6,0,0,0,1.11-2.83,43.12,43.12,0,0,0,.29-4.6V8.91A30.34,30.34,0,0,0,47.63,4.31Zm-22,11.86H23.71v-11h-2V3.34h6V5.17H25.66v11Zm6.89,0H30.69V15.11a2.64,2.64,0,0,1-1.91,1.17,1.21,1.21,0,0,1-1.14-.71,3.92,3.92,0,0,1-.2-1.4V6.6h1.83v7.74c0,.29.14.37.4.37s.66-.31,1.06-.86V6.6h1.83v9.57h0Zm6.6-2.86a7.6,7.6,0,0,1-.17,1.91,1.44,1.44,0,0,1-1.43,1.09,2.53,2.53,0,0,1-1.83-1.09v1H34V3.37h1.71V7.54a2.43,2.43,0,0,1,1.83-1.09,1.45,1.45,0,0,1,1.4,1.11,6.87,6.87,0,0,1,.23,1.91v3.83h0Zm3.83,1.4c.43,0,.66-.23.8-.69,0-.09,0-.51,0-1.2h1.83v.29c0,.54-.06.94-.06,1.11a2.16,2.16,0,0,1-.4,1,2.39,2.39,0,0,1-2.09,1,2.49,2.49,0,0,1-2.09-1,3.49,3.49,0,0,1-.6-2.2V9.8a3.88,3.88,0,0,1,.57-2.31,2.46,2.46,0,0,1,2.06-1,2.37,2.37,0,0,1,2,1,3.65,3.65,0,0,1,.57,2.23v2H42.11V13.4c0,.91.23,1.31.83,1.31Z"></path></svg>
#                 </span>
#               </a>
#             </li><li role="menuitem">
#               <a class="icon-link" href="http://www.oreilly.com/emails/newsletters/">
#                 <span class="icon icon-google t-fill icon--white">
#                   <svg height="20" id="email" viewBox="0 0 25 20" width="25" xmlns="http://www.w3.org/2000/svg"><title>Newsletters</title><path d="M22.5,0H2.5A2.5,2.5,0,0,0,0,2.5v15A2.51,2.51,0,0,0,2.5,20h20A2.51,2.51,0,0,0,25,17.5V2.5A2.51,2.51,0,0,0,22.5,0Zm0,5-10,6.25L2.5,5V2.5l10,6.25,10-6.25Z"></path></svg>
#                 </span>
#               </a>
#             </li>
#           </ul>
#         </div>
#       </div>
#     </div>
#
#     <div class="footer-bottom">
#       <div class="legal">
#         <a class="logo pa-bg" href="https://www.oreilly.com" title="O'Reilly home page"><img alt="O'Reilly home" onerror="this.src='//cdn.oreillystatic.com/images/sitewide-headers/oreilly-logo-reversed-130x23.png'; this.onerror=null;" src="//cdn.oreillystatic.com/images/sitewide-headers/oreilly-logo-norm.svg"/></a>
#         <p class="copyright">© 2017 O’Reilly Media, Inc. All trademarks and registered trademarks appearing on oreilly.com are the property of their respective owners.</p>
#
# <p class="amazon-services">We are a participant in the Amazon Services LLC Associates Program, an affiliate advertising program designed to provide a means for us to earn fees by linking to Amazon.com and affiliated sites.</p>
#
#
#         <p class="t-c pa-text"><a href="http://www.oreilly.com/terms/">Terms of Service</a> <span class="bullet">•</span> <a href="http://www.oreilly.com/privacy.html">Privacy Policy</a> <span class="bullet">•</span> <a href="http://www.oreilly.com/about/editorial_independence.html">Editorial Independence</a></p>
#       </div>
#
#       <figure class="animal">
#         <img alt="Tarsier" class="tarsier" src="//cdn.oreillystatic.com/images/sitewide-headers/tarsier-footer.png"/>
#       </figure>
#     </div>
#
#   </footer>
#     <!-- search bar - desktop behavior -->
#
#
#
#
#
# <script type="text/javascript">
#   function checkIfDefault(keyword) {
#     var defaultSearchTerm = "Search";
#     if(keyword==defaultSearchTerm) {
#       return '';
#     }
#     else {
#       return keyword;
#     }
#   }
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/yui/2.6.0/build/utilities/utilities.js" type="text/javascript"></script>
# <script src="//ajax.googleapis.com/ajax/libs/yui/2.6.0/build/datasource/datasource-min.js" type="text/javascript"></script>
# <script src="//ajax.googleapis.com/ajax/libs/yui/2.6.0/build/autocomplete/autocomplete-min.js" type="text/javascript"></script>
# <script src="//content.atomz.com/sp10049ed9/publish/autocomplete_data.js?sp_js_cache_ver=14" type="text/javascript"></script>
#
# </body></html>

# %% [markdown]
# ## python 日付のparser
# pythonには、優れた日付パーサーがない。dateutil.parser.parseが良い
# pip install python-dateutil

# %%
import dateutil.parser

print dateutil.parser.parse('2010/6/30 23:15:22')
print dateutil.parser.parse('2010-06-30')
print dateutil.parser.parse('20100630')
print dateutil.parser.parse('Mon, 27 Oct 2008 21:24:07 +0900 (JST)')
# Out:
# 2010-06-30 23:15:22
# 2010-06-30 00:00:00
# 2010-06-30 00:00:00
# 2008-10-27 21:24:07+09:00
# C:\ProgramData\Anaconda3\envs\py27\lib\site-packages\dateutil\parser.py:605: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif res.tzname and res.tzname in time.tzname:
